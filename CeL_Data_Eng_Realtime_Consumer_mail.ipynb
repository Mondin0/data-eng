# %% [markdown]
# <a href="https://colab.research.google.com/github/Mondin0/data-eng/blob/main/CeL_Data_Eng_Realtime_Consumer_mail.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install confluent-kafka
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 1.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 20.3 MB/s eta 0:00:00
# ...

# %%
from confluent_kafka import Consumer

# %%
kafka_config = {
    'bootstrap.servers': 'cstoobu6igjosi339b60.any.us-east-1.mpx.prd.cloud.redpanda.com:9092',
    'sasl.mechanism': 'SCRAM-SHA-256',
    'security.protocol': 'SASL_SSL',
    "group.id": "pythonConsumerApp",
    'sasl.username': 'usr',
    'sasl.password': 'gpCYTV1Mv0hMZKplGyzWD7uj6O2QBz',
    # Indica desde donde se consumiran los eventos del topico: earliest, latest
    'auto.offset.reset': 'latest',
}

consumer = Consumer(kafka_config)

# %%
consumer.subscribe(["logs"])

try:
    while True:
        msg = consumer.poll(1.0)

        if msg is None:
            continue
        if msg.error():
            if msg.error().code() == KafkaError._PARTITION_EOF:
                continue
            else:
                print(f'Error while consuming: {msg.error()}')
        else:
            # Acceder al campo value y decodificarlo
            value = msg.value().decode("utf-8")
            print(f'Recibido {value}')

except KeyboardInterrupt:
    pass
finally:
    # Close the consumer gracefully
    consumer.close()
# Out:
# Recibido 2024-11-19 23:49:18 - 70.126.165.132 - POST blog/wp-content/list - 500 - 10937
# Recibido 2024-11-19 23:49:39 - 218.55.186.157 - POST category/blog - 401 - 52449
# Recibido 2024-11-19 23:49:58 - 131.201.158.46 - POST posts/blog - 200 - 41503
# Recibido 2024-11-19 23:50:09 - 80.53.255.243 - GET explore/explore - 401 - 52533
# Recibido 2024-11-19 23:50:14 - 195.70.139.182 - GET app/tag/tag - 403 - 45025
# Recibido 2024-11-19 23:50:12 - 30.24.23.250 - POST list/list - 404 - 47199
# Recibido 2024-11-19 23:50:35 - 110.69.113.29 - POST list/main - 404 - 51397
# Recibido 2024-11-19 23:50:42 - 217.210.142.253 - POST explore/app - 200 - 29740
# Recibido 2024-11-19 23:50:35 - 122.216.195.173 - GET wp-content/wp-content/tag - 401 - 53651
# Recibido 2024-11-19 23:50:04 - 191.102.242.82 - GET search/posts/posts - 401 - 37858
# Recibido 2024-11-19 23:49:49 - 38.40.41.75 - POST wp-content/explore/main - 404 - 968
# ...
