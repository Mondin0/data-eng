# %% [markdown]
# <a href="https://colab.research.google.com/github/Mondin0/data-eng/blob/main/CeL_Data_Eng_Realtime_Consumer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install confluent-kafka
# Out:
# Collecting confluent-kafka
#   Downloading confluent_kafka-2.6.1-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 1.1 MB/s eta 0:00:00
# Downloading confluent_kafka-2.6.1-cp310-cp310-manylinux_2_28_x86_64.whl (3.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 24.4 MB/s eta 0:00:00
# Installing collected packages: confluent-kafka
# Successfully installed confluent-kafka-2.6.1

# %%
from confluent_kafka import Consumer

# %%
kafka_config = {
    'bootstrap.servers': 'cstoobu6igjosi339b60.any.us-east-1.mpx.prd.cloud.redpanda.com:9092',
    'sasl.mechanism': 'SCRAM-SHA-256',
    'security.protocol': 'SASL_SSL',
    "group.id": "pythonConsumerApp",
    'sasl.username': 'usr',
    'sasl.password': 'gpCYTV1Mv0hMZKplGyzWD7uj6O2QBz',
    # Indica desde donde se consumiran los eventos del topico: earliest, latest
    'auto.offset.reset': 'latest',
}

consumer = Consumer(kafka_config)

# %%
consumer.subscribe(["logs"])

try:
    while True:
        msg = consumer.poll(1.0)

        if msg is None:
            continue
        if msg.error():
            if msg.error().code() == KafkaError._PARTITION_EOF:
                continue
            else:
                print(f'Error while consuming: {msg.error()}')
        else:
            # Acceder al campo value y decodificarlo
            value = msg.value().decode("utf-8")
            print(f'Recibido {value}')

except KeyboardInterrupt:
    pass
finally:
    # Close the consumer gracefully
    consumer.close()
# Out:
# Recibido 2024-11-20 00:19:25 - 2.42.226.174 - POST list - 401 - 42368
# Recibido 2024-11-20 00:19:29 - 138.101.143.30 - GET app/wp-content - 401 - 21476
# Recibido 2024-11-20 00:19:18 - 67.145.85.34 - POST search/posts/category - 500 - 46302
# Recibido 2024-11-20 00:19:01 - 73.194.3.160 - POST categories/main/search - 401 - 22349
# Recibido 2024-11-20 00:19:07 - 170.1.231.25 - GET search - 401 - 39535
# Recibido 2024-11-20 00:19:47 - 55.47.246.38 - POST explore/list - 500 - 14524
# Recibido 2024-11-20 00:19:29 - 87.229.16.243 - POST search/tags/main - 404 - 34026
# Recibido 2024-11-20 00:19:44 - 49.97.78.63 - POST main/category/explore - 200 - 980
# Recibido 2024-11-20 00:19:58 - 58.239.122.133 - POST blog/wp-content/category - 404 - 60767
# Recibido 2024-11-20 00:20:08 - 147.172.3.2 - GET list/categories/main - 404 - 60693
# Recibido 2024-11-20 00:19:45 - 182.214.159.218 - GET tags/posts/app - 500 - 16961
# Recibido 2024-11-20 00:20:12 - 85.73.179.247 - POST tag - 200 - 21887
# Recibido 2024-11-20 00:19:58 - 75.183.181.186 - GET posts/posts/explore - 401 - 13383
# Recibido 2024-11-20 00:19:35 - 135.223.177.37 - POST blog/explore - 500 - 62124
# Recibido 2024-11-20 00:19:26 - 49.20.160.169 - POST categories/wp-content/main - 403 - 39200
# Recibido 2024-11-20 00:19:45 - 136.5.237.60 - POST explore/tags/categories - 401 - 52208
# Recibido 2024-11-20 00:24:32 - 78.65.119.223 - GET category/wp-content - 404 - 46398
# Recibido 2024-11-20 00:25:08 - 136.225.21.96 - POST explore - 403 - 18705
# Recibido 2024-11-20 00:24:41 - 42.180.91.231 - GET category/explore - 401 - 3837
# Recibido 2024-11-20 00:24:41 - 27.195.115.28 - POST wp-content - 200 - 42952
# Recibido 2024-11-20 00:24:49 - 70.95.21.101 - POST blog - 404 - 6626
# Recibido 2024-11-20 00:24:29 - 76.113.3.100 - GET category/wp-content/tags - 404 - 57411
# Recibido 2024-11-20 00:24:40 - 57.236.231.222 - GET app/main/search - 200 - 31445
# Recibido 2024-11-20 00:24:49 - 138.72.243.59 - GET tag/blog - 404 - 14868
# Recibido 2024-11-20 00:25:07 - 162.166.172.17 - GET explore - 401 - 55275
# Recibido 2024-11-20 00:25:10 - 178.232.60.173 - GET blog - 200 - 42337
# Recibido 2024-11-20 00:25:03 - 136.253.90.226 - POST main/search - 403 - 38317
# Recibido 2024-11-20 00:24:21 - 108.253.105.37 - POST main/tags - 401 - 9052
# Recibido 2024-11-20 00:24:37 - 148.67.91.162 - POST explore/app - 500 - 17771
# Recibido 2024-11-20 00:24:50 - 40.22.251.207 - GET app/tags - 500 - 30467
# Recibido 2024-11-20 00:25:11 - 189.219.42.240 - GET blog/list/main - 500 - 37230
# Recibido 2024-11-20 00:25:07 - 27.134.216.140 - POST tags/category/explore - 401 - 26718
# Recibido 2024-11-20 00:25:13 - 111.124.27.169 - POST blog/wp-content - 403 - 58087
# Recibido 2024-11-20 00:25:29 - 46.111.234.254 - POST search/tag/wp-content - 404 - 53259
# Recibido 2024-11-20 00:25:22 - 11.107.253.37 - POST tags/wp-content/blog - 401 - 7204
# Recibido 2024-11-20 00:25:17 - 95.59.23.201 - GET tags - 200 - 5272
# Recibido 2024-11-20 00:25:24 - 60.197.157.178 - GET tag/main - 403 - 40489
# Recibido 2024-11-20 00:25:41 - 15.236.83.77 - POST posts - 500 - 24870
# Recibido 2024-11-20 00:25:14 - 61.129.134.67 - GET tag/blog - 200 - 53297
# Recibido 2024-11-20 00:25:14 - 124.23.239.108 - POST tag - 500 - 58703
# Recibido 2024-11-20 00:25:05 - 10.142.182.44 - POST app - 403 - 24595
# Recibido 2024-11-20 00:25:41 - 188.173.37.24 - POST main/list - 200 - 64397
# Recibido 2024-11-20 00:24:46 - 110.240.48.234 - POST main/app/list - 500 - 14077
# Recibido 2024-11-20 00:24:59 - 112.187.146.204 - GET search/tags/app - 403 - 51601
# Recibido 2024-11-20 00:25:30 - 187.152.75.152 - GET search/categories/search - 500 - 18975
# Recibido 2024-11-20 00:24:52 - 205.117.56.59 - GET tags/explore/app - 403 - 8667
# Recibido 2024-11-20 00:25:08 - 107.79.13.62 - POST categories - 401 - 64455
# Recibido 2024-11-20 00:25:29 - 57.205.26.59 - POST list/category - 200 - 60043
# Recibido 2024-11-20 00:25:38 - 130.27.61.142 - GET wp-content/tag - 401 - 36946
# Recibido 2024-11-20 00:25:17 - 136.70.159.61 - POST posts - 403 - 13737
